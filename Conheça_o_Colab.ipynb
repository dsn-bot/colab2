# %% [markdown]
# <a href="https://colab.research.google.com/github/dsn-bot/colab2/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dados = {
    "nome1": str(input("Digite seu nome:"))
    "idade1": int(input("Digite sua idade:"))
    "nome2": str(input("Digite seu nome:"))
    "idade2": int(input("Digite sua idade:"))
}

print(dados)
# Out:
#   File "/tmp/ipykernel_17720/1425517044.py", line 2
#     "nome1": str(input("Digite seu nome:"))
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Usuário 1
nome1 = str(input("Digite o nome do primeiro usuário: "))
idade1 = int(input("Digite a idade do primeiro usuário: "))

# Usuário 2
nome2 = str(input("Digite o nome do segundo usuário: "))
idade2 = int(input("Digite a idade do segundo usuário: "))

dados = {
    "usuario1": {
        "nome": nome1,
        "idade": idade1
    },

    "usuario2": {
        "nome": nome2,
        "idade": idade2
    }
}

print(dados)
# Out:
# Digite o nome do primeiro usuário: josé
# Digite a idade do primeiro usuário: 14
# Digite o nome do segundo usuário: almeida
# Digite a idade do segundo usuário: 74
# {'usuario1': {'nome': 'josé', 'idade': 14}, 'usuario2': {'nome': 'almeida', 'idade': 74}}

# %%
# Usuário1
nome = str(input("Digite seu nome: "))
idade = int(input("Digite seu idade: "))
cidade = str(input("Digite seu cidade: "))

dados = {
    "usuario1": {
        "Nome": nome,
        "Idade": idade,
        "Cidade": cidade
    }
}



print ( "Olá, ", nome, ", Você tem ", idade, " anos, e mora em ", cidade,".")
# Out:
# Digite seu nome: Silas
# Digite seu idade: 19
# Digite seu cidade: Aracaju
# Olá,  Silas , Você tem  19  anos, e mora em  Aracaju .
